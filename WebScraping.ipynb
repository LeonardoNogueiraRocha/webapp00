# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoNogueiraRocha/webapp00/blob/main/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install GoogleNews
from GoogleNews import GoogleNews
import pandas as pd
googlenews=GoogleNews(period='d')
googlenews.setlang('pt')

googlenews.search('UEFA champions league')
googlenews.result()
result=googlenews.result()
df=pd.DataFrame(result)
df.head()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.3 MB/s eta 0:00:00
# ...
#                                                title           media  \
# 0  Pesquisa revela qual torneio de futebol é mais...  Bolavip Brasil
# 1  UEFA Champions League de 2024/25: Itália e Ale...        UEFA.com
# 2  Com treino de finalizações, Fluminense segue p...             MSN
# 3  Borussia Dortmund x Real Madrid: de trave caíd...      TNT Sports
# 4  Espetáculo das apostas: principais ligas e tor...      AlagoasWeb
#
#          date  datetime                                               desc  \
# 0  á 10 horas       NaN  Os campeonatos nacionais e continentais têm a ...
# 1  á 10 horas       NaN  Corpo do artigo. A UEFA Champions League de 20...
# 2  á 12 horas       NaN  O Fluminense treinou nesta segunda-feira, no C...
# 3  á 13 horas       NaN  Finalistas da Champions League 2023/24, Boruss...
# 4  á 13 horas       NaN  As apostas esportivas são uma busca estimulant...
#
# ...

# %%
entrada = input("Digite o que pesquisar:")
googlenews.search(entrada)
googlenews.result()
result=googlenews.result()
df=pd.DataFrame(result)
df.head()
# Out:
# Digite o que pesquisar:Jogos UEFA
#                                                title           media  \
# 0  Pesquisa revela qual torneio de futebol é mais...  Bolavip Brasil
# 1  UEFA Champions League de 2024/25: Itália e Ale...        UEFA.com
# 2  Com treino de finalizações, Fluminense segue p...             MSN
# 3  Borussia Dortmund x Real Madrid: de trave caíd...      TNT Sports
# 4  Espetáculo das apostas: principais ligas e tor...      AlagoasWeb
#
#          date  datetime                                               desc  \
# 0  á 10 horas       NaN  Os campeonatos nacionais e continentais têm a ...
# 1  á 10 horas       NaN  Corpo do artigo. A UEFA Champions League de 20...
# 2  á 12 horas       NaN  O Fluminense treinou nesta segunda-feira, no C...
# 3  á 13 horas       NaN  Finalistas da Champions League 2023/24, Boruss...
# 4  á 13 horas       NaN  As apostas esportivas são uma busca estimulant...
#
#                                                 link  \
# ...
